# %% [markdown]
# ### Import libraries

# %%
#Import the required Python libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Import solar output dataset

# %%
data = pd.read_csv('./PV_Output_Hannover_MA.csv')

# %%
#Reading the solar output data measure as %baseline
data
# Out:
#               Timestamp  % Baseline
# 0       Jan 1, 2014 7am      0.0079
# 1       Jan 1, 2014 8am      0.1019
# 2       Jan 1, 2014 9am      0.3932
# 3      Jan 1, 2014 10am      0.5447
# 4      Jan 1, 2014 11am      0.5485
# ...                 ...         ...
# 20566   Mar 5, 2018 1pm      0.2325
# 20567   Mar 5, 2018 2pm      0.2214
# 20568   Mar 5, 2018 3pm      0.3111
# 20569   Mar 5, 2018 4pm      0.0810
# 20570   Mar 5, 2018 5pm      0.0150
#
# [20571 rows x 2 columns]

# %%
#Adding longitude and latitude in place of City, County and State
data['Latitude'] ='42.13'
data['Longitude'] ='-70.86'

# %%
data
# Out:
#               Timestamp  % Baseline Latitude Longitude
# 0       Jan 1, 2014 7am      0.0079    42.13    -70.86
# 1       Jan 1, 2014 8am      0.1019    42.13    -70.86
# 2       Jan 1, 2014 9am      0.3932    42.13    -70.86
# 3      Jan 1, 2014 10am      0.5447    42.13    -70.86
# 4      Jan 1, 2014 11am      0.5485    42.13    -70.86
# ...                 ...         ...      ...       ...
# 20566   Mar 5, 2018 1pm      0.2325    42.13    -70.86
# 20567   Mar 5, 2018 2pm      0.2214    42.13    -70.86
# 20568   Mar 5, 2018 3pm      0.3111    42.13    -70.86
# 20569   Mar 5, 2018 4pm      0.0810    42.13    -70.86
# 20570   Mar 5, 2018 5pm      0.0150    42.13    -70.86
#
# [20571 rows x 4 columns]

# %%
#Change Timestamp column to datetime
data['Timestamp'] = pd.to_datetime(data['Timestamp'])

# %% [markdown]
# ### Making an API call to www.worldweatheronline.com to retrieve weather data for Hanover, Massachusetts location between 2014 and 2018

# %%
#Retrieving weather data from www.worldweatheronline.com into pandas dataframe and csv.
# from wwo_hist import retrieve_hist_data
# import os
# #writing csv file to the output folder
# os.chdir("./output")
# frequency = 1
# start_date = '01-JAN-2014'
# end_date = '03-05-2018'
# api_key = 'YOUR_API_KEY'
# location_list = ['02340']
# hist_weather_data = retrieve_hist_data(api_key,
#                                 location_list,
#                                 start_date,
#                                 end_date,
#                                 frequency,
#                                 location_label = False,
#                                 export_csv = True,
#                                 store_df = True)

# %%
weather_df = pd.read_csv('./output/02340.csv')

# %%
weather_df
# Out:
#                  date_time  maxtempC  mintempC  totalSnow_cm  sunHour  \
# 0      2014-01-01 00:00:00        -3        -6           0.0      8.7
# 1      2014-01-01 01:00:00        -3        -6           0.0      8.7
# 2      2014-01-01 02:00:00        -3        -6           0.0      8.7
# 3      2014-01-01 03:00:00        -3        -6           0.0      8.7
# 4      2014-01-01 04:00:00        -3        -6           0.0      8.7
# ...                    ...       ...       ...           ...      ...
# 36595  2018-03-05 19:00:00         4         1           0.0      5.7
# 36596  2018-03-05 20:00:00         4         1           0.0      5.7
# 36597  2018-03-05 21:00:00         4         1           0.0      5.7
# 36598  2018-03-05 22:00:00         4         1           0.0      5.7
# 36599  2018-03-05 23:00:00         4         1           0.0      5.7
#
#        uvIndex  moon_illumination  moonrise   moonset   sunrise  ...  \
# 0            2                  1  06:58 AM  05:05 PM  07:12 AM  ...
# 1            2                  1  06:58 AM  05:05 PM  07:12 AM  ...
# 2            2                  1  06:58 AM  05:05 PM  07:12 AM  ...
# 3            2                  1  06:58 AM  05:05 PM  07:12 AM  ...
# 4            2                  1  06:58 AM  05:05 PM  07:12 AM  ...
# ...        ...                ...       ...       ...       ...  ...
# 36595        1                 79  09:49 PM  08:24 AM  06:12 AM  ...
# 36596        1                 79  09:49 PM  08:24 AM  06:12 AM  ...
# 36597        1                 79  09:49 PM  08:24 AM  06:12 AM  ...
# 36598        1                 79  09:49 PM  08:24 AM  06:12 AM  ...
# 36599        1                 79  09:49 PM  08:24 AM  06:12 AM  ...
#
#       WindGustKmph  cloudcover  humidity  precipMM  pressure  tempC  \
# 0               28           3        58       0.0      1022     -4
# 1               31           4        58       0.0      1023     -5
# 2               34           5        58       0.0      1024     -5
# 3               36           6        58       0.0      1024     -5
# 4               32           9        57       0.0      1025     -6
# ...            ...         ...       ...       ...       ...    ...
# 36595           35          61        76       0.0      1016      3
# 36596           38          65        76       0.0      1017      3
# 36597           40          69        76       0.0      1017      3
# 36598           39          75        75       0.0      1017      2
# 36599           37          81        75       0.0      1017      2
#
#        visibility  winddirDegree  windspeedKmph  location
# 0              10            273             20      2340
# 1              10            274             22      2340
# 2              10            276             25      2340
# 3              10            278             27      2340
# 4              10            271             23      2340
# ...           ...            ...            ...       ...
# 36595          10             13             21      2340
# 36596          10             17             23      2340
# 36597          10             21             24      2340
# 36598          10             19             24      2340
# 36599          10             18             24      2340
#
# [36600 rows x 25 columns]

# %%
#Change date_time column to datetime
weather_df['date_time'] = pd.to_datetime(weather_df['date_time'])
#Deleting some of the columns
del weather_df['location']
del weather_df['moonrise']
del weather_df['moonset']
del weather_df['sunrise']
del weather_df['sunset']

# %%
#Merging weather data with the original solar output data
outcome = pd.merge(data, weather_df, how='left', left_on='Timestamp', right_on='date_time')

# %%
del outcome['date_time']

# %%
outcome
# Out:
#                 Timestamp  % Baseline Latitude Longitude  maxtempC  mintempC  \
# 0     2014-01-01 07:00:00      0.0079    42.13    -70.86        -3        -6
# 1     2014-01-01 08:00:00      0.1019    42.13    -70.86        -3        -6
# 2     2014-01-01 09:00:00      0.3932    42.13    -70.86        -3        -6
# 3     2014-01-01 10:00:00      0.5447    42.13    -70.86        -3        -6
# 4     2014-01-01 11:00:00      0.5485    42.13    -70.86        -3        -6
# ...                   ...         ...      ...       ...       ...       ...
# 20566 2018-03-05 13:00:00      0.2325    42.13    -70.86         4         1
# 20567 2018-03-05 14:00:00      0.2214    42.13    -70.86         4         1
# 20568 2018-03-05 15:00:00      0.3111    42.13    -70.86         4         1
# 20569 2018-03-05 16:00:00      0.0810    42.13    -70.86         4         1
# 20570 2018-03-05 17:00:00      0.0150    42.13    -70.86         4         1
#
#        totalSnow_cm  sunHour  uvIndex  moon_illumination  ...  WindChillC  \
# 0               0.0      8.7        2                  1  ...         -13
# 1               0.0      8.7        2                  1  ...         -12
# 2               0.0      8.7        2                  1  ...         -11
# 3               0.0      8.7        2                  1  ...         -10
# 4               0.0      8.7        2                  1  ...         -10
# ...             ...      ...      ...                ...  ...         ...
# 20566           0.0      5.7        1                 79  ...          -2
# 20567           0.0      5.7        1                 79  ...          -1
# 20568           0.0      5.7        1                 79  ...          -1
# 20569           0.0      5.7        1                 79  ...          -2
# 20570           0.0      5.7        1                 79  ...          -2
#
#        WindGustKmph  cloudcover  humidity  precipMM  pressure  tempC  \
# 0                24          13        52       0.0      1027     -5
# 1                26          11        49       0.0      1027     -5
# 2                27           9        46       0.0      1028     -4
# 3                25          15        46       0.0      1028     -4
# 4                23          21        45       0.0      1027     -3
# ...             ...         ...       ...       ...       ...    ...
# 20566            47          74        71       0.1      1015      4
# 20567            45          53        70       0.0      1015      4
# 20568            43          32        69       0.0      1015      4
# 20569            40          40        72       0.0      1015      4
# 20570            36          49        74       0.0      1016      3
#
#        visibility  winddirDegree  windspeedKmph
# 0              10            262             18
# 1              10            266             20
# 2              10            270             22
# 3              10            273             21
# 4              10            276             19
# ...           ...            ...            ...
# 20566           9             20             36
# 20567          10             20             33
# 20568          10             21             31
# 20569          10             17             27
# 20570          10             13             23
#
# [20571 rows x 23 columns]

# %% [markdown]
# ### Reading Solar Irradiance datasets from https://nsrdb.nrel.gov/ for 2014, 2015, 2016, 2017 and 2018

# %%
# Reading Solar irradiance data for the year 2014 from National Solar Radiation Database
df1= pd.read_csv('./Weather_data_2014.csv')

# %%
df1
# Out:
#       Year  Month  Day  Hour  Minute  DHI  DNI  GHI  Clearsky DHI  \
# 0     2014      1    1     0       0    0    0    0             0
# 1     2014      1    1     1       0    0    0    0             0
# 2     2014      1    1     2       0    0    0    0             0
# 3     2014      1    1     3       0    0    0    0             0
# 4     2014      1    1     4       0    0    0    0             0
# ...    ...    ...  ...   ...     ...  ...  ...  ...           ...
# 8755  2014     12   31    19       0   68  500  195            57
# 8756  2014     12   31    20       0   44   65   52            36
# 8757  2014     12   31    21       0    0    0    0             0
# 8758  2014     12   31    22       0    0    0    0             0
# 8759  2014     12   31    23       0    0    0    0             0
#
#       Clearsky DNI  Clearsky GHI  Cloud Type  Dew Point  Solar Zenith Angle  \
# 0                0             0           1         -6              124.02
# 1                0             0           1         -5              135.09
# 2                0             0           1         -5              145.77
# 3                0             0           1         -6              155.07
# 4                0             0           1         -8              160.55
# ...            ...           ...         ...        ...                 ...
# 8755           727           241           4         -9               75.32
# 8756           498            96           4         -9               83.08
# 8757             0             0           4         -7               92.22
# 8758             0             0           1         -7              102.30
# 8759             0             0           1         -7              113.01
#
#       Fill Flag  Surface Albedo  Wind Speed  Relative Humidity  Temperature  \
# 0             0           0.120         3.5              78.43           -3
# 1             0           0.120         3.8              81.74           -3
# 2             0           0.120         4.2              81.25           -3
# 3             0           0.120         4.5              74.14           -3
# 4             0           0.120         4.6              72.80           -4
# ...         ...             ...         ...                ...          ...
# 8755          0           0.108         2.8              52.99           -1
# 8756          4           0.108         2.7              58.58           -2
# 8757          0           0.108         2.7              68.56           -3
# 8758          0           0.108         2.8              70.16           -3
# 8759          0           0.108         2.8              69.91           -4
#
#       Pressure
# 0         1010
# 1         1010
# 2         1010
# 3         1010
# 4         1010
# ...        ...
# 8755      1010
# 8756      1010
# 8757      1010
# 8758      1010
# 8759      1010
#
# [8760 rows x 20 columns]

# %%
# Reading Solar irradiance data for the year 2015 from National Solar Radiation Database
df2= pd.read_csv('./Weather_data_2015.csv')

# %%
df2
# Out:
#       Year  Month  Day  Hour  Minute  DHI  DNI  GHI  Clearsky DHI  \
# 0     2015      1    1     0       0    0    0    0             0
# 1     2015      1    1     1       0    0    0    0             0
# 2     2015      1    1     2       0    0    0    0             0
# 3     2015      1    1     3       0    0    0    0             0
# 4     2015      1    1     4       0    0    0    0             0
# ...    ...    ...  ...   ...     ...  ...  ...  ...           ...
# 8755  2015     12   31    19       0   58  668  227            58
# 8756  2015     12   31    20       0   36    0   36            37
# 8757  2015     12   31    21       0    0    0    0             0
# 8758  2015     12   31    22       0    0    0    0             0
# 8759  2015     12   31    23       0    0    0    0             0
#
#       Clearsky DNI  Clearsky GHI  Cloud Type  Dew Point  Solar Zenith Angle  \
# 0                0             0           1         -8              124.05
# 1                0             0           1         -8              135.13
# 2                0             0           1         -8              145.80
# 3                0             0           4         -8              155.10
# 4                0             0           4         -8              160.58
# ...            ...           ...         ...        ...                 ...
# 8755           668           227           1          2               75.35
# 8756           430            89           4          2               83.11
# 8757             0             0           7          2               92.25
# 8758             0             0           7          2              102.34
# 8759             0             0           4          1              113.04
#
#       Fill Flag  Surface Albedo  Wind Speed  Relative Humidity  Temperature  \
# 0             0           0.109         2.7              73.23           -4
# 1             0           0.109         2.7              70.66           -4
# 2             0           0.109         2.9              74.69           -5
# 3             0           0.109         3.2              69.42           -4
# 4             0           0.109         3.5              69.79           -4
# ...         ...             ...         ...                ...          ...
# 8755          0           0.113         3.5              84.47            5
# 8756          4           0.113         3.6              89.77            4
# 8757          0           0.113         3.7              95.17            3
# 8758          0           0.113         3.7              93.63            3
# 8759          0           0.113         3.7              92.27            3
#
#       Pressure
# 0         1010
# 1         1010
# 2         1010
# 3         1010
# 4         1010
# ...        ...
# 8755      1010
# 8756      1010
# 8757      1010
# 8758      1010
# 8759      1010
#
# [8760 rows x 20 columns]

# %%
# Reading Solar irradiance data for the year 2016 from National Solar Radiation Database
df3= pd.read_csv('./Weather_data_2016.csv')

# %%
df3
# Out:
#       Year  Month  Day  Hour  Minute  DHI  DNI  GHI  Clearsky DHI  \
# 0     2016      1    1     0       0    0    0    0             0
# 1     2016      1    1     1       0    0    0    0             0
# 2     2016      1    1     2       0    0    0    0             0
# 3     2016      1    1     3       0    0    0    0             0
# 4     2016      1    1     4       0    0    0    0             0
# ...    ...    ...  ...   ...     ...  ...  ...  ...           ...
# 8779  2016     12   31    19       0   71  597  223            71
# 8780  2016     12   31    20       0   42  374   87            42
# 8781  2016     12   31    21       0    0    0    0             0
# 8782  2016     12   31    22       0    0    0    0             0
# 8783  2016     12   31    23       0    0    0    0             0
#
#       Clearsky DNI  Clearsky GHI  Cloud Type  Dew Point  Solar Zenith Angle  \
# 0                0             0           1          1              124.08
# 1                0             0           8          1              135.16
# 2                0             0           8          1              145.83
# 3                0             0           4          0              155.13
# 4                0             0           8          0              160.60
# ...            ...           ...         ...        ...                 ...
# 8779           597           223           1         -2               75.26
# 8780           374            87           1         -2               83.02
# 8781             0             0           1         -1               92.15
# 8782             0             0           1          0              102.24
# 8783             0             0           1          0              112.94
#
#       Fill Flag  Surface Albedo  Wind Speed  Relative Humidity  Temperature  \
# 0             0           0.108         3.5              97.77            2
# 1             0           0.108         3.5              95.82            2
# 2             0           0.108         3.5             100.00            1
# 3             0           0.108         3.5              99.59            1
# 4             0           0.108         3.5              98.21            1
# ...         ...             ...         ...                ...          ...
# 8779          1           0.113         3.8              74.89            1
# 8780          1           0.113         4.0              79.96            1
# 8781          1           0.113         4.3              85.65            1
# 8782          1           0.113         4.6              85.65            2
# 8783          1           0.113         4.8              85.77            3
#
#       Pressure
# 0         1010
# 1         1010
# 2         1010
# 3         1010
# 4         1010
# ...        ...
# 8779      1010
# 8780      1010
# 8781      1010
# 8782      1010
# 8783      1010
#
# [8784 rows x 20 columns]

# %%
# Reading Solar irradiance data for the year 2017 from National Solar Radiation Database
df4= pd.read_csv('./Weather_data_2017.csv')

# %%
df4
# Out:
#       Year  Month  Day  Hour  Minute  DHI  DNI  GHI  Clearsky DHI  \
# 0     2017      1    1     0       0    0    0    0             0
# 1     2017      1    1     1       0    0    0    0             0
# 2     2017      1    1     2       0    0    0    0             0
# 3     2017      1    1     3       0    0    0    0             0
# 4     2017      1    1     4       0    0    0    0             0
# ...    ...    ...  ...   ...     ...  ...  ...  ...           ...
# 8755  2017     12   31    19       0   60  581  208            62
# 8756  2017     12   31    20       0   42  349   84            37
# 8757  2017     12   31    21       0    0    0    0             0
# 8758  2017     12   31    22       0    0    0    0             0
# 8759  2017     12   31    23       0    0    0    0             0
#
#       Clearsky DNI  Clearsky GHI  Cloud Type  Dew Point  Solar Zenith Angle  \
# 0                0             0           8          1              123.98
# 1                0             0           6          2              135.06
# 2                0             0           6          3              145.73
# 3                0             0           6          3              155.03
# 4                0             0           6          3              160.53
# ...            ...           ...         ...        ...                 ...
# 8755           754           254           8        -13               75.29
# 8756           541           102           4        -13               83.05
# 8757             0             0           4        -13               92.18
# 8758             0             0           1        -13              102.27
# 8759             0             0           4        -14              112.97
#
#       Fill Flag  Surface Albedo  Wind Speed  Relative Humidity  Temperature  \
# 0             0           0.109         5.1              85.43            4
# 1             0           0.109         5.2              90.60            4
# 2             0           0.109         5.1              88.62            5
# 3             0           0.109         4.8              90.55            5
# 4             0           0.109         4.6              95.19            4
# ...         ...             ...         ...                ...          ...
# 8755          4           0.866         4.8              67.82           -9
# 8756          4           0.866         4.8              73.91          -10
# 8757          0           0.866         4.8              79.66          -11
# 8758          0           0.866         4.9              85.39          -12
# 8759          0           0.866         4.9              84.26          -12
#
#       Pressure
# 0         1010
# 1         1000
# 2         1000
# 3         1000
# 4         1000
# ...        ...
# 8755      1010
# 8756      1010
# 8757      1010
# 8758      1010
# 8759      1010
#
# [8760 rows x 20 columns]

# %%
# Reading Solar irradiance data for the year 2018 from National Solar Radiation Database
df5= pd.read_csv('./Weather_data_2018.csv')

# %%
df5
# Out:
#       Year  Month  Day  Hour  Minute  DHI  DNI  GHI  Clearsky DHI  \
# 0     2018      1    1     0       0    0    0    0             0
# 1     2018      1    1     1       0    0    0    0             0
# 2     2018      1    1     2       0    0    0    0             0
# 3     2018      1    1     3       0    0    0    0             0
# 4     2018      1    1     4       0    0    0    0             0
# ...    ...    ...  ...   ...     ...  ...  ...  ...           ...
# 8755  2018     12   31    19       0   86  338  172            54
# 8756  2018     12   31    20       0   43  194   67            36
# 8757  2018     12   31    21       0    0    0    0             0
# 8758  2018     12   31    22       0    0    0    0             0
# 8759  2018     12   31    23       0    0    0    0             0
#
#       Clearsky DNI  Clearsky GHI  Cloud Type  Dew Point  Solar Zenith Angle  \
# 0                0             0           4      -14.4              124.01
# 1                0             0           4      -14.6              135.09
# 2                0             0           4      -14.8              145.76
# 3                0             0           4      -15.0              155.06
# 4                0             0           4      -15.2              160.54
# ...            ...           ...         ...        ...                 ...
# 8755           694           231           7        1.2               75.26
# 8756           474            94           8        1.2               82.96
# 8757             0             0           8        1.1               92.22
# 8758             0             0           7        1.0              102.31
# 8759             0             0           8        1.1              113.01
#
#       Fill Flag  Surface Albedo  Wind Speed  Relative Humidity  Temperature  \
# 0             0            0.87         4.0              88.71        -12.9
# 1             0            0.87         4.0              89.11        -13.2
# 2             0            0.87         4.0              90.29        -13.6
# 3             0            0.87         3.9              92.63        -14.1
# 4             0            0.87         3.9              94.46        -14.5
# ...         ...             ...         ...                ...          ...
# 8755         86            0.12         2.4              84.61          3.5
# 8756        100            0.12         2.6              87.96          3.0
# 8757          0            0.12         2.7              89.51          2.7
# 8758          0            0.12         2.7              89.90          2.5
# 8759          0            0.12         2.8              90.33          2.5
#
#       Pressure
# 0         1019
# 1         1019
# 2         1019
# 3         1019
# 4         1019
# ...        ...
# 8755      1022
# 8756      1021
# 8757      1022
# 8758      1021
# 8759      1021
#
# [8760 rows x 20 columns]

# %%
#Stacking all the Solar irradiance data into one dataframe 
result = pd.concat([df1,df2, df3, df4, df5], ignore_index=True)

# %%
result
# Out:
#        Year  Month  Day  Hour  Minute  DHI  DNI  GHI  Clearsky DHI  \
# 0      2014      1    1     0       0    0    0    0             0
# 1      2014      1    1     1       0    0    0    0             0
# 2      2014      1    1     2       0    0    0    0             0
# 3      2014      1    1     3       0    0    0    0             0
# 4      2014      1    1     4       0    0    0    0             0
# ...     ...    ...  ...   ...     ...  ...  ...  ...           ...
# 43819  2018     12   31    19       0   86  338  172            54
# 43820  2018     12   31    20       0   43  194   67            36
# 43821  2018     12   31    21       0    0    0    0             0
# 43822  2018     12   31    22       0    0    0    0             0
# 43823  2018     12   31    23       0    0    0    0             0
#
#        Clearsky DNI  Clearsky GHI  Cloud Type  Dew Point  Solar Zenith Angle  \
# 0                 0             0           1       -6.0              124.02
# 1                 0             0           1       -5.0              135.09
# 2                 0             0           1       -5.0              145.77
# 3                 0             0           1       -6.0              155.07
# 4                 0             0           1       -8.0              160.55
# ...             ...           ...         ...        ...                 ...
# 43819           694           231           7        1.2               75.26
# 43820           474            94           8        1.2               82.96
# 43821             0             0           8        1.1               92.22
# 43822             0             0           7        1.0              102.31
# 43823             0             0           8        1.1              113.01
#
#        Fill Flag  Surface Albedo  Wind Speed  Relative Humidity  Temperature  \
# 0              0            0.12         3.5              78.43         -3.0
# 1              0            0.12         3.8              81.74         -3.0
# 2              0            0.12         4.2              81.25         -3.0
# 3              0            0.12         4.5              74.14         -3.0
# 4              0            0.12         4.6              72.80         -4.0
# ...          ...             ...         ...                ...          ...
# 43819         86            0.12         2.4              84.61          3.5
# 43820        100            0.12         2.6              87.96          3.0
# 43821          0            0.12         2.7              89.51          2.7
# 43822          0            0.12         2.7              89.90          2.5
# 43823          0            0.12         2.8              90.33          2.5
#
#        Pressure
# 0          1010
# 1          1010
# 2          1010
# 3          1010
# 4          1010
# ...         ...
# 43819      1022
# 43820      1021
# 43821      1022
# 43822      1021
# 43823      1021
#
# [43824 rows x 20 columns]

# %%
#Combining Year Month Day Hour Minute column into a single datatime column(easy to merge on the date_time column with 
#the final dataframe)
result['date_time']= pd.to_datetime(result[['Year', 'Month', 'Day', 'Hour', 'Minute']])
#Delete the individual columns after combining
del result['Year']
del result['Month']
del result['Day']
del result['Hour']
del result['Minute']

# %%
#Merge the final dataframe with the above Solar irradiance data
merged_df = pd.merge(outcome, result, how='left', left_on='Timestamp', right_on='date_time')

# %%
del merged_df['date_time']

# %%
#Deleting duplicate columns from the dataset
merged_df['Year'] = merged_df['Timestamp'].dt.year
merged_df['Month'] = merged_df['Timestamp'].dt.month
merged_df['Day'] = merged_df['Timestamp'].dt.day
merged_df['Hour'] = merged_df['Timestamp'].dt.hour
merged_df['Minute'] = merged_df['Timestamp'].dt.minute

# %%
del merged_df['Timestamp']

# %%
merged_df
# Out:
#        % Baseline Latitude Longitude  maxtempC  mintempC  totalSnow_cm  \
# 0          0.0079    42.13    -70.86        -3        -6           0.0
# 1          0.1019    42.13    -70.86        -3        -6           0.0
# 2          0.3932    42.13    -70.86        -3        -6           0.0
# 3          0.5447    42.13    -70.86        -3        -6           0.0
# 4          0.5485    42.13    -70.86        -3        -6           0.0
# ...           ...      ...       ...       ...       ...           ...
# 20566      0.2325    42.13    -70.86         4         1           0.0
# 20567      0.2214    42.13    -70.86         4         1           0.0
# 20568      0.3111    42.13    -70.86         4         1           0.0
# 20569      0.0810    42.13    -70.86         4         1           0.0
# 20570      0.0150    42.13    -70.86         4         1           0.0
#
#        sunHour  uvIndex  moon_illumination  DewPointC  ...  Surface Albedo  \
# 0          8.7        2                  1        -14  ...            0.12
# 1          8.7        2                  1        -14  ...            0.12
# 2          8.7        2                  1        -14  ...            0.12
# 3          8.7        2                  1        -14  ...            0.12
# 4          8.7        2                  1        -14  ...            0.12
# ...        ...      ...                ...        ...  ...             ...
# 20566      5.7        1                 79         -1  ...            0.87
# 20567      5.7        1                 79         -1  ...            0.87
# 20568      5.7        1                 79         -1  ...            0.87
# 20569      5.7        1                 79         -1  ...            0.87
# 20570      5.7        1                 79         -1  ...            0.87
#
#        Wind Speed  Relative Humidity  Temperature  Pressure  Year  Month  Day  \
# 0             4.4              69.95         -5.0      1020  2014      1    1
# 1             4.3              74.24         -6.0      1020  2014      1    1
# 2             4.3              73.07         -6.0      1020  2014      1    1
# 3             4.1              72.43         -6.0      1020  2014      1    1
# 4             3.9              72.47         -6.0      1020  2014      1    1
# ...           ...                ...          ...       ...   ...    ...  ...
# 20566         5.5              87.86          1.9      1010  2018      3    5
# 20567         5.6              84.15          2.5      1010  2018      3    5
# 20568         5.7              79.86          3.2      1010  2018      3    5
# 20569         5.7              76.97          3.7      1010  2018      3    5
# 20570         5.6              74.94          4.1      1010  2018      3    5
#
#        Hour  Minute
# 0         7       0
# 1         8       0
# 2         9       0
# 3        10       0
# 4        11       0
# ...     ...     ...
# 20566    13       0
# 20567    14       0
# 20568    15       0
# 20569    16       0
# 20570    17       0
#
# [20571 rows x 42 columns]

# %%
merged_df.dtypes
# Out:
# % Baseline            float64
# Latitude               object
# Longitude              object
# maxtempC                int64
# mintempC                int64
# totalSnow_cm          float64
# sunHour               float64
# uvIndex                 int64
# moon_illumination       int64
# DewPointC               int64
# FeelsLikeC              int64
# HeatIndexC              int64
# WindChillC              int64
# WindGustKmph            int64
# cloudcover              int64
# humidity                int64
# precipMM              float64
# pressure                int64
# tempC                   int64
# visibility              int64
# winddirDegree           int64
# windspeedKmph           int64
# DHI                     int64
# DNI                     int64
# GHI                     int64
# Clearsky DHI            int64
# Clearsky DNI            int64
# Clearsky GHI            int64
# Cloud Type              int64
# Dew Point             float64
# Solar Zenith Angle    float64
# Fill Flag               int64
# Surface Albedo        float64
# Wind Speed            float64
# Relative Humidity     float64
# Temperature           float64
# Pressure                int64
# Year                    int64
# Month                   int64
# Day                     int64
# Hour                    int64
# Minute                  int64
# dtype: object

# %%
merged_df.shape
# Out:
# (20571, 42)

# %%
#View the column names of the dataframe
col_names = merged_df.columns
col_names
# Out:
# Index(['% Baseline', 'Latitude', 'Longitude', 'maxtempC', 'mintempC',
#        'totalSnow_cm', 'sunHour', 'uvIndex', 'moon_illumination', 'DewPointC',
#        'FeelsLikeC', 'HeatIndexC', 'WindChillC', 'WindGustKmph', 'cloudcover',
#        'humidity', 'precipMM', 'pressure', 'tempC', 'visibility',
#        'winddirDegree', 'windspeedKmph', 'DHI', 'DNI', 'GHI', 'Clearsky DHI',
#        'Clearsky DNI', 'Clearsky GHI', 'Cloud Type', 'Dew Point',
#        'Solar Zenith Angle', 'Fill Flag', 'Surface Albedo', 'Wind Speed',
#        'Relative Humidity', 'Temperature', 'Pressure', 'Year', 'Month', 'Day',
#        'Hour', 'Minute'],
#       dtype='object')

# %%
# check distribution of %Baseline column
merged_df['% Baseline'].value_counts()
# Out:
# 0.0023    196
# 0.0022    123
# 0.0002    102
# 0.0028     83
# 0.0004     73
#          ...
# 0.5140      1
# 0.2803      1
# 0.7262      1
# 0.1743      1
# 0.1626      1
# Name: % Baseline, Length: 6723, dtype: int64

# %%
# view the percentage distribution of target_class column
merged_df['% Baseline'].value_counts()/np.float(len(merged_df))
# Out:
# 0.0023    0.009528
# 0.0022    0.005979
# 0.0002    0.004958
# 0.0028    0.004035
# 0.0004    0.003549
#             ...
# 0.5140    0.000049
# 0.2803    0.000049
# 0.7262    0.000049
# 0.1743    0.000049
# 0.1626    0.000049
# Name: % Baseline, Length: 6723, dtype: float64

# %%
# view summary of dataset
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20571 entries, 0 to 20570
# Data columns (total 42 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   % Baseline          20571 non-null  float64
#  1   Latitude            20571 non-null  object
#  2   Longitude           20571 non-null  object
#  3   maxtempC            20571 non-null  int64
#  4   mintempC            20571 non-null  int64
#  5   totalSnow_cm        20571 non-null  float64
#  6   sunHour             20571 non-null  float64
#  7   uvIndex             20571 non-null  int64
#  8   moon_illumination   20571 non-null  int64
#  9   DewPointC           20571 non-null  int64
#  10  FeelsLikeC          20571 non-null  int64
#  11  HeatIndexC          20571 non-null  int64
#  12  WindChillC          20571 non-null  int64
#  13  WindGustKmph        20571 non-null  int64
#  14  cloudcover          20571 non-null  int64
#  15  humidity            20571 non-null  int64
#  16  precipMM            20571 non-null  float64
#  17  pressure            20571 non-null  int64
#  18  tempC               20571 non-null  int64
#  19  visibility          20571 non-null  int64
#  20  winddirDegree       20571 non-null  int64
#  21  windspeedKmph       20571 non-null  int64
#  22  DHI                 20571 non-null  int64
#  23  DNI                 20571 non-null  int64
#  24  GHI                 20571 non-null  int64
#  25  Clearsky DHI        20571 non-null  int64
#  26  Clearsky DNI        20571 non-null  int64
#  27  Clearsky GHI        20571 non-null  int64
#  28  Cloud Type          20571 non-null  int64
#  29  Dew Point           20571 non-null  float64
#  30  Solar Zenith Angle  20571 non-null  float64
#  31  Fill Flag           20571 non-null  int64
#  32  Surface Albedo      20571 non-null  float64
#  33  Wind Speed          20571 non-null  float64
#  34  Relative Humidity   20571 non-null  float64
#  35  Temperature         20571 non-null  float64
#  36  Pressure            20571 non-null  int64
#  37  Year                20571 non-null  int64
#  38  Month               20571 non-null  int64
#  39  Day                 20571 non-null  int64
#  40  Hour                20571 non-null  int64
#  41  Minute              20571 non-null  int64
# dtypes: float64(10), int64(30), object(2)
# memory usage: 6.7+ MB

# %%
#Checking for null values in the dataset before modeling
merged_df.isnull().sum()
# Out:
# % Baseline            0
# Latitude              0
# Longitude             0
# maxtempC              0
# mintempC              0
# totalSnow_cm          0
# sunHour               0
# uvIndex               0
# moon_illumination     0
# DewPointC             0
# FeelsLikeC            0
# HeatIndexC            0
# WindChillC            0
# WindGustKmph          0
# cloudcover            0
# humidity              0
# precipMM              0
# pressure              0
# tempC                 0
# visibility            0
# winddirDegree         0
# windspeedKmph         0
# DHI                   0
# DNI                   0
# GHI                   0
# Clearsky DHI          0
# Clearsky DNI          0
# Clearsky GHI          0
# Cloud Type            0
# Dew Point             0
# Solar Zenith Angle    0
# Fill Flag             0
# Surface Albedo        0
# Wind Speed            0
# Relative Humidity     0
# Temperature           0
# Pressure              0
# Year                  0
# Month                 0
# Day                   0
# Hour                  0
# Minute                0
# dtype: int64

# %%
# view summary statistics in numerical variables
round(merged_df.describe(),2)
# Out:
#        % Baseline  maxtempC  mintempC  totalSnow_cm   sunHour   uvIndex  \
# count    20571.00  20571.00  20571.00      20571.00  20571.00  20571.00
# mean         0.24     14.76      8.36          0.12     10.41      3.77
# std          0.25      9.53      8.56          0.85      3.40      1.74
# min          0.00    -12.00    -20.00          0.00      3.40      1.00
# 25%          0.03      7.00      2.00          0.00      8.70      2.00
# 50%          0.13     15.00      9.00          0.00     11.20      4.00
# 75%          0.39     23.00     16.00          0.00     13.50      5.00
# max          1.02     32.00     23.00         22.20     14.50      7.00
#
#        moon_illumination  DewPointC  FeelsLikeC  HeatIndexC  ...  \
# count           20571.00   20571.00    20571.00    20571.00  ...
# mean               50.25       7.22       10.83       12.89  ...
# std                28.91       9.28       11.74        9.74  ...
# min                 0.00     -22.00      -32.00      -20.00  ...
# 25%                25.00       1.00        2.00        5.00  ...
# 50%                50.00       9.00       12.00       13.00  ...
# 75%                75.00      15.00       20.00       21.00  ...
# max               100.00      25.00       36.00       36.00  ...
#
#        Surface Albedo  Wind Speed  Relative Humidity  Temperature  Pressure  \
# count        20571.00    20571.00           20571.00     20571.00  20571.00
# mean             0.21        2.59              81.44        10.87   1007.63
# std              0.23        1.33              16.97         9.48      8.76
# min              0.11        0.10              30.31       -19.00    970.00
# 25%              0.12        1.60              68.30         3.00   1000.00
# 50%              0.13        2.40              85.21        11.00   1010.00
# 75%              0.14        3.30              97.75        19.00   1010.00
# max              0.87       11.00             100.00        32.00   1040.00
#
#            Year     Month       Day      Hour   Minute
# count  20571.00  20571.00  20571.00  20571.00  20571.0
# mean    2015.55      6.42     15.73     11.98      0.0
# std        1.17      3.24      8.86      4.21      0.0
# min     2014.00      1.00      1.00      0.00      0.0
# 25%     2015.00      4.00      8.00      8.00      0.0
# 50%     2016.00      6.00     16.00     12.00      0.0
# 75%     2017.00      9.00     23.00     15.00      0.0
# max     2018.00     12.00     31.00     21.00      0.0
#
# [8 rows x 40 columns]

# %% [markdown]
# ## Linear Regression Model with Python and Scikit-Learn

# %% [markdown]
# ### Declare feature vector and target variable

# %%
X = merged_df.drop(['% Baseline'], axis=1)
y= merged_df['% Baseline']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print('Coefficients: \n', model.coef_)
# Out:
# Coefficients:
#  [ 9.86426440e-17  2.08470394e-15 -1.84676434e-02 -1.03385767e-02
#  -2.04036864e-03  2.56177905e-03 -1.76301931e-02  6.69366562e-05
#  -1.16010929e-02  1.07418190e-02  4.42761127e-03 -1.18122168e-03
#  -7.13664190e-03 -8.25630901e-04 -1.77991600e-03 -4.45726469e-04
#  -6.60440058e-04  4.11487827e-02 -5.52165690e-04 -7.54359515e-05
#   1.22437280e-02  2.37736043e-04  1.29152366e-04 -2.70930688e-05
#   4.89333740e-04  2.90505984e-05 -2.72077167e-04 -4.20829610e-03
#  -6.66848944e-03 -4.34910483e-03 -2.95188918e-04 -4.04508735e-02
#  -3.29963535e-03  1.40413134e-03 -5.69147120e-03  3.83587109e-04
#  -1.16863740e-02 -8.11763078e-03  2.69996891e-04 -2.47888031e-02
#   0.00000000e+00]

# %%
predictions = model.predict(X_test)

# %%
plt.scatter(y_test,predictions)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 0.11327842985387372
# MSE: 0.021483427333992437
# RMSE: 0.14657225976968644

# %%
coeffecients = pd.DataFrame(model.coef_,X.columns)
coeffecients.columns = ['Coeffecient']
coeffecients
# Out:
#                      Coeffecient
# Latitude            9.864264e-17
# Longitude           2.084704e-15
# maxtempC           -1.846764e-02
# mintempC           -1.033858e-02
# totalSnow_cm       -2.040369e-03
# sunHour             2.561779e-03
# uvIndex            -1.763019e-02
# moon_illumination   6.693666e-05
# DewPointC          -1.160109e-02
# FeelsLikeC          1.074182e-02
# HeatIndexC          4.427611e-03
# WindChillC         -1.181222e-03
# WindGustKmph       -7.136642e-03
# cloudcover         -8.256309e-04
# humidity           -1.779916e-03
# precipMM           -4.457265e-04
# pressure           -6.604401e-04
# tempC               4.114878e-02
# visibility         -5.521657e-04
# winddirDegree      -7.543595e-05
# windspeedKmph       1.224373e-02
# DHI                 2.377360e-04
# DNI                 1.291524e-04
# GHI                -2.709307e-05
# Clearsky DHI        4.893337e-04
# Clearsky DNI        2.905060e-05
# Clearsky GHI       -2.720772e-04
# Cloud Type         -4.208296e-03
# Dew Point          -6.668489e-03
# Solar Zenith Angle -4.349105e-03
# Fill Flag          -2.951889e-04
# Surface Albedo     -4.045087e-02
# Wind Speed         -3.299635e-03
# Relative Humidity   1.404131e-03
# Temperature        -5.691471e-03
# Pressure            3.835871e-04
# Year               -1.168637e-02
# Month              -8.117631e-03
# Day                 2.699969e-04
# Hour               -2.478880e-02
# Minute              0.000000e+00

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# Fitting our model with all our features in X
model.fit(X, y)

score = model.score(X, y)
print(f"R2 Score: {score}")
# Out:
# R2 Score: 0.6763805816961562

# %%
print('Weight coefficients: ', model.coef_)
print('y-axis intercept: ', model.intercept_)
# Out:
# Weight coefficients:  [ 3.00591570e-16 -2.25340580e-15 -1.86598020e-02 -1.08491579e-02
#  -6.11026256e-04  2.63224913e-03 -1.76922739e-02  7.96912420e-05
#  -1.16693896e-02  9.35701876e-03  5.53159642e-03  1.14073338e-03
#  -7.08027204e-03 -8.36788782e-04 -1.78110238e-03  8.41445587e-05
#  -6.49626240e-04  3.93394926e-02 -3.42106609e-04 -8.60329306e-05
#   1.21327042e-02  2.43337132e-04  1.31182199e-04 -2.64359477e-05
#   5.05773796e-04  3.50853353e-05 -2.77348575e-04 -4.01690051e-03
#  -6.77797752e-03 -4.34352108e-03 -3.19877073e-04 -4.05916281e-02
#  -2.39963537e-03  1.50377646e-03 -5.20246967e-03  3.08536380e-04
#  -1.17028755e-02 -8.33513048e-03  2.38802907e-04 -2.52930643e-02
#   0.00000000e+00]
# y-axis intercept:  24.83720696949684

# %%
predictions = model.predict(X)
print(f"True output: {y[0]}")
print(f"Predicted output: {predictions[0]}")
print(f"Prediction Error: {predictions[0]-y[0]}")
# Out:
# True output: 0.0079
# Predicted output: 0.11981115230720008
# Prediction Error: 0.11191115230720007

# %%
pd.DataFrame({"Predicted": predictions, "Actual": y, "Error": predictions - y})[["Predicted", "Actual", "Error"]]
# Out:
#        Predicted  Actual     Error
# 0       0.119811  0.0079  0.111911
# 1       0.169111  0.1019  0.067211
# 2       0.275627  0.3932 -0.117573
# 3       0.304616  0.5447 -0.240084
# 4       0.369309  0.5485 -0.179191
# ...          ...     ...       ...
# 20566   0.264991  0.2325  0.032491
# 20567   0.249528  0.2214  0.028128
# 20568   0.263746  0.3111 -0.047354
# 20569   0.164310  0.0810  0.083310
# 20570   0.073304  0.0150  0.058304
#
# [20571 rows x 3 columns]
